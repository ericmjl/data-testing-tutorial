# %%
import pandas as pd
import missingno as msno

# %%
sanitization_df = pd.read_csv('data/smartphone_sanitization.csv')
sanitization_df
# Out:
#      sample_id    treatment  colonies_pre  colonies_post  morphologies_pre  \
# 0            1    phonesoap             0              0                 0
# 1            2    phonesoap            12              0                 3
# 2            3    phonesoap            14              4                 5
# 3            4      ethanol             0              0                 0
# 4            5      ethanol             0              1                 0
# 5            6      ethanol             1              0                 1
# 6            7    phonesoap            19              0                 7
# 7            8    phonesoap            29              0                 3
# 8            9    phonesoap            50              8                 8
# 9           10   bleachwipe             0              0                 0
# 10          11   bleachwipe            12              1                 5
# ...

# %%
msno.matrix(sanitization_df)

# %%
msno.bar(sanitization_df)

# %%
stations = pd.read_csv('data/Divvy_Stations_2013.csv')

stations.head()# msno.geoplot(stations)
# Out:
#    id                        name   latitude  longitude  dpcapacity  landmark  \
# 0   5      State St & Harrison St  41.873958 -87.627739          19        30
# 1  13  Wilton Ave & Diversey Pkwy  41.932500 -87.652681          19        66
# 2  14         Morgan St & 18th St  41.858086 -87.651073          15       163
# 3  15        Racine Ave & 18th St  41.858181 -87.656487          15       164
# 4  16         Wood St & North Ave  41.910329 -87.672516          15       223
#
#   online date
# 0   6/28/2013
# 1   6/28/2013
# 2   6/28/2013
# 3   6/28/2013
# 4   8/12/2013

# %%
msno.geoplot(stations, x='latitude', y='longitude', coordinates)
