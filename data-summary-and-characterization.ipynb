# %%
import pandas as pd

# %%
df = pd.read_csv('data/smartphone_sanitization.csv')
df.head()
# Out:
#    sample_id  treatment  colonies_pre  colonies_post  morphologies_pre  \
# 0          1  phonesoap             0              0                 0
# 1          2  phonesoap            12              0                 3
# 2          3  phonesoap            14              4                 5
# 3          4    ethanol             0              0                 0
# 4          5    ethanol             0              1                 0
#
#    morphologies_post    year  month   day      site  phone ID  no case  \
# 0                  0  2015.0   10.0   7.0     phone         4      NaN
# 1                  0  2015.0   10.0   7.0  junction         4      NaN
# 2                  2  2015.0   10.0   7.0      case         4      NaN
# 3                  0  2016.0    4.0  20.0     phone         4      NaN
# 4                  1  2016.0    4.0  20.0  junction         4      NaN
#
#   screen protector
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# ...

# %%
# Schema & data types
df.dtypes
# Out:
# sample_id              int64
# treatment             object
# colonies_pre           int64
# colonies_post          int64
# morphologies_pre       int64
# morphologies_post      int64
# year                 float64
# month                float64
# day                  float64
# site                  object
# phone ID               int64
# no case              float64
# screen protector      object
# dtype: object

# %%
df.describe()
# Out:
#         sample_id  colonies_pre  colonies_post  morphologies_pre  \
# count  182.000000    182.000000     182.000000        182.000000
# mean    91.500000     19.252747       4.021978          2.972527
# std     52.683014     23.327642       7.713056          1.741376
# min      1.000000      0.000000       0.000000          0.000000
# 25%     46.250000      4.000000       0.000000          2.000000
# 50%     91.500000     11.000000       1.000000          3.000000
# 75%    136.750000     24.500000       4.000000          4.000000
# max    182.000000    100.000000      47.000000          8.000000
#
#        morphologies_post         year      month        day    phone ID  \
# count         182.000000    70.000000  70.000000  70.000000  182.000000
# mean            1.170330  2015.400000   8.342857  11.671429   21.758242
# std             1.370002     0.493435   3.265479   4.924713   15.301999
# min             0.000000  2015.000000   4.000000   7.000000    1.000000
# ...
